# %%
import pandas as pd
import dask.dataframe as dd

# %%
# Read the CSV files into pandas dataframes
df1 = pd.read_csv('dataset/Code_cell.csv')

# %%
# Changing the dataframe
df1 = df1[['cell_id', 'notebook_id', 'code_imports', 'defined_functions', 'source']]

# %%
df1.to_pickle('df1.pkl')
df1.head(20)
# Out:
#     cell_id  notebook_id                              code_imports  \
# 0         1            1               json pprint dateutil.parser
# 1         2            1                                       NaN
# 2         3            1                                       NaN
# 3         4            1                                       NaN
# 4         6            2                                        os
# 5         7            2                                       NaN
# 6         9            2                                       NaN
# 7        11            2                                       NaN
# 8        13            2             google.datalab.ml.TensorBoard
# 9        14            2                                       NaN
# 10       18            2                                       NaN
# 11       20            2  json codecs matplotlib.pyplot tensorflow
# 12       22            2                                       NaN
# 13       24            2                                       NaN
# 14       26            2                                       NaN
# 15       29            3                   subprocess.check_output
# 16       30            3                              numpy pandas
# 17       68            3                                       NaN
# 18       85            4                         matplotlib.pyplot
# 19      126            4                                       NaN
#
#    defined_functions                                             source
# 0                NaN  import json\nimport pprint\n\nimport dateutil....
# 1                NaN  submission['created_at'] = dateutil.parser.par...
# 2                NaN                          pprint.pprint(submission)
# 3                NaN                                                NaN
# 4                NaN  import os\nPROJECT = "cloud-training-demos" # ...
# 5                NaN  %%bash\ngcloud config set project $PROJECT\ngc...
# 6                NaN  %%bash\nrm -rf mnistmodel.tar.gz mnist_trained...
# 7                NaN  %%bash\nOUTDIR=gs://${BUCKET}/mnist/trained_${...
# 8                NaN  from google.datalab.ml import TensorBoard\nTen...
# 9                NaN  for pid in TensorBoard.list()["pid"]:\n    Ten...
# 10               NaN  %%bash\nMODEL_NAME="mnist"\nMODEL_VERSION=${MO...
# 11               NaN  import json, codecs\nimport matplotlib.pyplot ...
# 12               NaN  %%bash\ngcloud ml-engine predict \\n    --mode...
# 13               NaN  trainingInput:\n    scaleTier: CUSTOM\n    mas...
# 14               NaN  %%bash\nOUTDIR=gs://${BUCKET}/mnist/trained_${...
# 15               NaN  from subprocess import check_output\nprint(che...
# 16               NaN            import numpy as np\nimport pandas as pd
# 17               NaN                                   embedding_matrix
# 18               NaN  import matplotlib.pyplot as plt\n%matplotlib i...
# 19               NaN                                                NaN

# %%
df2 = pd.read_csv('dataset/Md_cell.csv')

# %%
# Changing the dataframe
df2 = df2[['cell_id', 'notebook_id', 'source']]

# %%
df2.to_pickle('df2.pkl')
df2.head(20)
# Out:
#     cell_id  notebook_id                                             source
# 0         5            2  # MNIST Image Classification with TensorFlow o...
# 1         8            2  ## Run as a Python module\n\nIn the previous n...
# 2        10            2  **Now, let's do it on Cloud ML Engine so we ca...
# 3        12            2  ## Monitoring training with TensorBoard\n\nUse...
# 4        15            2  Here's what it looks like with a linear model ...
# 5        16            2  Here are my results:\n\nModel | Accuracy | Tim...
# 6        17            2  ## Deploying and predicting with model\n\nDepl...
# 7        19            2  To predict with the model, let's take one of t...
# 8        21            2                  Send it to the prediction service
# 9        23            2  ## DO NOT RUN anything beyond this point\n\nTh...
# 10       25            2  This takes <b>13 hours and 250 ML Units</b>, s...
# 11       27            2  <pre>\n# Copyright 2017 Google Inc. All Rights...
# 12       28            3                      # Keras - Bidirectional LSTM
# 13       31            3                              ### Import keras Libs
# 14       56            3       ### Read Glove Word Vectors : word -> vector
# 15       76            3                        ## Submission File Generate
# 16       82            4             # Logistic Regression (Classification)
# 17       83            4  So far we have been looking at regression prob...
# 18       88            4  Lets say we want to classify the vehicles by '...
# 19       92            4  ## Why Linear Function does not work\nNow we c...

# %%
# load dataframes from pickle files
df1 = pd.read_pickle('df1.pkl')
df_code = df1.head(1000000)
df2 = pd.read_pickle('df2.pkl')
df_md = df2.head(1000000)

# %%
# Merge dataframes based on the common column
merged_df = dd.merge(df_code, df_md, on='notebook_id', how='outer')

# %% [markdown]
# This code cell provides insights from our data analysis project, covering objectives, methodology, and key findings.We cover data preprocessing, exploratory data analysis (EDA), and model evaluation.

# %%
# Filter rows based on the condition
merged_df = merged_df.loc[merged_df['cell_id_x'] > merged_df['cell_id_y']]

# Keep the last Markdown cell before the Code cell while removing duplicates
merged_df.drop_duplicates(subset=['cell_id_x'], keep='last', inplace=True)

# If you want to reset the index after removing rows
merged_df.reset_index(drop=True, inplace=True)

merged_df.head(50)
# Out:
#     cell_id_x  notebook_id                                       code_imports  \
# 0         6.0            2                                                 os
# 1         7.0            2                                                NaN
# 2         9.0            2                                                NaN
# 3        11.0            2                                                NaN
# 4        13.0            2                      google.datalab.ml.TensorBoard
# 5        14.0            2                                                NaN
# 6        18.0            2                                                NaN
# 7        20.0            2           json codecs matplotlib.pyplot tensorflow
# 8        22.0            2                                                NaN
# 9        24.0            2                                                NaN
# 10       26.0            2                                                NaN
# 11       29.0            3                            subprocess.check_output
# 12       30.0            3                                       numpy pandas
# 13       68.0            3                                                NaN
# 14       32.0            3  keras.models.Model keras.layers.Dense keras.la...
# 15       33.0            3                                                NaN
# 16       34.0            3                                                NaN
# 17       35.0            3                                                NaN
# 18       36.0            3                                                NaN
# 19       37.0            3                                                NaN
# 20       38.0            3                                                NaN
# 21       39.0            3                                                NaN
# 22       40.0            3                                                NaN
# 23       41.0            3                                                NaN
# 24       42.0            3                                                NaN
# 25       43.0            3                                                NaN
# 26       44.0            3                                                NaN
# 27       45.0            3                                                NaN
# 28       46.0            3                                                NaN
# 29       47.0            3                                                NaN
# 30       48.0            3                                                NaN
# 31       49.0            3                                                NaN
# 32       50.0            3                                                NaN
# 33       51.0            3                                                NaN
# 34       52.0            3                                                NaN
# 35       53.0            3                                                NaN
# 36       54.0            3                                                NaN
# 37       55.0            3                                                NaN
# 38       57.0            3                                                NaN
# 39       58.0            3                                                NaN
# 40       59.0            3                                                NaN
# 41       60.0            3                                                NaN
# 42       61.0            3                                                NaN
# 43       62.0            3                                                NaN
# 44       63.0            3                                                NaN
# 45       64.0            3                                                NaN
# 46       65.0            3                                                NaN
# 47       66.0            3                                                NaN
# 48       67.0            3                                                NaN
# 49       69.0            3                                                NaN
#
#    defined_functions                                           source_x  \
# 0                NaN  import os\nPROJECT = "cloud-training-demos" # ...
# 1                NaN  %%bash\ngcloud config set project $PROJECT\ngc...
# 2                NaN  %%bash\nrm -rf mnistmodel.tar.gz mnist_trained...
# 3                NaN  %%bash\nOUTDIR=gs://${BUCKET}/mnist/trained_${...
# 4                NaN  from google.datalab.ml import TensorBoard\nTen...
# 5                NaN  for pid in TensorBoard.list()["pid"]:\n    Ten...
# 6                NaN  %%bash\nMODEL_NAME="mnist"\nMODEL_VERSION=${MO...
# 7                NaN  import json, codecs\nimport matplotlib.pyplot ...
# 8                NaN  %%bash\ngcloud ml-engine predict \\n    --mode...
# 9                NaN  trainingInput:\n    scaleTier: CUSTOM\n    mas...
# 10               NaN  %%bash\nOUTDIR=gs://${BUCKET}/mnist/trained_${...
# 11               NaN  from subprocess import check_output\nprint(che...
# 12               NaN            import numpy as np\nimport pandas as pd
# 13               NaN                                   embedding_matrix
# 14               NaN  from keras.models import Model\nfrom keras.lay...
# 15               NaN  EMBEDDING_FILE = f'glove.6B.50d.txt'\nTRAIN_DA...
# 16               NaN  max_features = 20000\nmaxlen = 100\nembed_size...
# 17               NaN               train = pd.read_csv(TRAIN_DATA_FILE)
# 18               NaN                                       train.head()
# 19               NaN  #train = train.sample(frac=1)\ntest = pd.read_...
# 20               NaN                                        test.head()
# 21               NaN  list_sentences_train = train['comment_text'].f...
# 22               NaN                       #print(list_sentences_train)
# 23               NaN  list_classes = ["toxic", "severe_toxic", "obsc...
# 24               NaN                                       list_classes
# 25               NaN                     y = train[list_classes].values
# 26               NaN                                                  y
# 27               NaN                                            y.shape
# 28               NaN  list_sentences_test = test['comment_text'].fil...
# 29               NaN                        #print(list_sentences_test)
# 30               NaN  tokenizer = text.Tokenizer(num_words=max_featu...
# 31               NaN                                   print(tokenizer)
# 32               NaN  tokenizer.fit_on_texts(list(list_sentences_tra...
# 33               NaN  list_tokenized_train = tokenizer.texts_to_sequ...
# 34               NaN                        print(list_tokenized_train)
# 35               NaN  X_t = sequence.pad_sequences(list_tokenized_tr...
# 36               NaN                                          X_t.shape
# 37               NaN                                         X_te.shape
# 38         get_coefs  def get_coefs(word,*arr): \n    return word, n...
# 39               NaN     all_embs = np.stack(embeddings_index.values())
# 40               NaN  emb_mean,emb_std = all_embs.mean(), all_embs.s...
# 41               NaN                                   emb_mean,emb_std
# 42               NaN                  word_index = tokenizer.word_index
# 43               NaN                                  print(word_index)
# 44               NaN      nb_words = min(max_features, len(word_index))
# 45               NaN                                           nb_words
# 46               NaN  embedding_matrix = np.random.normal(emb_mean, ...
# 47               NaN                                   embedding_matrix
# 48               NaN  for word, i in word_index.items():\n    if i >...
# 49         get_model  def get_model():\n    inp = Input(shape=(maxle...
#
#     cell_id_y                                           source_y
# 0         5.0  # MNIST Image Classification with TensorFlow o...
# 1         5.0  # MNIST Image Classification with TensorFlow o...
# 2         8.0  ## Run as a Python module\n\nIn the previous n...
# 3        10.0  **Now, let's do it on Cloud ML Engine so we ca...
# 4        12.0  ## Monitoring training with TensorBoard\n\nUse...
# 5        12.0  ## Monitoring training with TensorBoard\n\nUse...
# 6        17.0  ## Deploying and predicting with model\n\nDepl...
# 7        19.0  To predict with the model, let's take one of t...
# 8        21.0                  Send it to the prediction service
# 9        23.0  ## DO NOT RUN anything beyond this point\n\nTh...
# 10       25.0  This takes <b>13 hours and 250 ML Units</b>, s...
# 11       28.0                      # Keras - Bidirectional LSTM
# 12       28.0                      # Keras - Bidirectional LSTM
# 13       56.0       ### Read Glove Word Vectors : word -> vector
# 14       31.0                              ### Import keras Libs
# 15       31.0                              ### Import keras Libs
# 16       31.0                              ### Import keras Libs
# 17       31.0                              ### Import keras Libs
# 18       31.0                              ### Import keras Libs
# 19       31.0                              ### Import keras Libs
# 20       31.0                              ### Import keras Libs
# 21       31.0                              ### Import keras Libs
# 22       31.0                              ### Import keras Libs
# 23       31.0                              ### Import keras Libs
# 24       31.0                              ### Import keras Libs
# 25       31.0                              ### Import keras Libs
# 26       31.0                              ### Import keras Libs
# 27       31.0                              ### Import keras Libs
# 28       31.0                              ### Import keras Libs
# 29       31.0                              ### Import keras Libs
# 30       31.0                              ### Import keras Libs
# 31       31.0                              ### Import keras Libs
# 32       31.0                              ### Import keras Libs
# 33       31.0                              ### Import keras Libs
# 34       31.0                              ### Import keras Libs
# 35       31.0                              ### Import keras Libs
# 36       31.0                              ### Import keras Libs
# 37       31.0                              ### Import keras Libs
# 38       56.0       ### Read Glove Word Vectors : word -> vector
# 39       56.0       ### Read Glove Word Vectors : word -> vector
# 40       56.0       ### Read Glove Word Vectors : word -> vector
# 41       56.0       ### Read Glove Word Vectors : word -> vector
# 42       56.0       ### Read Glove Word Vectors : word -> vector
# 43       56.0       ### Read Glove Word Vectors : word -> vector
# 44       56.0       ### Read Glove Word Vectors : word -> vector
# 45       56.0       ### Read Glove Word Vectors : word -> vector
# 46       56.0       ### Read Glove Word Vectors : word -> vector
# 47       56.0       ### Read Glove Word Vectors : word -> vector
# 48       56.0       ### Read Glove Word Vectors : word -> vector
# 49       56.0       ### Read Glove Word Vectors : word -> vector

# %%
# Save the merged dataframe to a new pickle file
merged_df.to_pickle('df_train.pkl')

# %%
# Save the dataset as csv file
merged_df.to_csv('merged_file.csv')
